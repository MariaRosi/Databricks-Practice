-- %%
create table datacentre.bronze.order

-- %%
copy into datacentre.bronze.order
from '/Volumes/datacentre/bronze/input_stream/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

-- %%
select * from datacentre.bronze.order

-- %%
copy into datacentre.bronze.order
from '/Volumes/datacentre/bronze/input_stream/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

-- %%
select * from datacentre.bronze.order
