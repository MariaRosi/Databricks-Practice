# %%
# %sql
create table datacentre.bronze.users (
  userId INT,
  username STRING,
  email STRING
);

# %%
# %sql
insert into datacentre.bronze.users values
      (1, 'john.smith', 'john.smith@dcom'),
      (2, NULL, 'david.clear@com'),
      (3, 'kevin.smith', 'kevin.smith@com');

# %%
# %sql
select * from datacentre.bronze.users

# %%
# %sql
select count(*) from datacentre.bronze.users;
    
select count(1) from datacentre.bronze.users;

select
count(*),
count(username),
count(distinct *)from datacentre.bronze.users;
