# %% [markdown]
# ### Select Dataframe

# %%
emp_df = spark.read.csv('/Volumes/datacentre/bronze/input_files/employee_large.csv', inferSchema=True, header=True)

# %%
display(emp_df)

# %%
display(emp_df.select("employee_id", "first_name", "last_name", "email"))

# %%
from pyspark.sql.functions import col

display(emp_df.select(col("employee_id"), col("first_name"), col("last_name"), col("email")))

# %%
display(emp_df.select(emp_df.employee_id, emp_df.first_name, emp_df.last_name, emp_df.email))

# %%
display(emp_df.select(emp_df["employee_id"], emp_df["first_name"], emp_df["last_name"], emp_df["email"]))

# %%
display(emp_df.select(col("employee_id").alias("employee id")))

# %%
display(emp_df.take(2))

# %%
display(emp_df.tail(2))

# %%
display(emp_df.describe())

# %%
display(emp_df.describe(['salary']))

# %%
display(emp_df.select("*"))

# %%
emp_df.dtypes

# %%
emp_df.printSchema
