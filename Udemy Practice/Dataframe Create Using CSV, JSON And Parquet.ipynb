# %%
# %sql
CREATE SCHEMA udemy_practice_catalog.udemy_practice_schema

# %%
# %sql
create volume udemy_practice_catalog.udemy_practice_schema.udemy_practice_volume

# %% [markdown]
# ### **CREATE FRAMRAME**

# %%
df = spark.read.csv('/Volumes/udemy_practice_catalog/udemy_practice_schema/udemy_practice_volume/orders/orders.csv', header=True)
display(df)

# %%
df = spark.read.format('csv').option('header','True').load('/Volumes/udemy_practice_catalog/udemy_practice_schema/udemy_practice_volume/orders/orders.csv')
display(df)

# %% [markdown]
# ### # **Check the schema details and infer schema**

# %%
df.printSchema()

# %%
df = spark.read.format("csv").option("header","True").option("inferSchema","True").load("/Volumes/udemy_practice_catalog/udemy_practice_schema/udemy_practice_volume/orders/orders.csv")
display(df)

# %%
df.printSchema()

# %% [markdown]
# ### **Read from json file**

# %%
df = spark.read.format("json").option("multiline", "True").load("/Volumes/udemy_practice_catalog/udemy_practice_schema/udemy_practice_volume/orders/order_json.json")

display(df)

# %% [markdown]
# ### **Read parquet file**

# %%
df = spark.read.parquet("/Volumes/udemy_practice_catalog/udemy_practice_schema/udemy_practice_volume/orders/orders.parquet")

display(df)
