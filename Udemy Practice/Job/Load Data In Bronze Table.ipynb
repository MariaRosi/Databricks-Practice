# %%
df = spark.read.csv("/Volumes/udemy_practice_catalog/udemy_practice_schema/udemy_practice_volume/raw_sales_orders/raw_sales_orders.csv", header=True)

df.display()

# %%
df.write.mode("overwrite").saveAsTable("udemy_practice_catalog.bronze.raw_sales_orders")

# %%
# %sql
select * from udemy_practice_catalog.bronze.raw_sales_orders
