# %%
import importlib
import common

importlib.reload(common)

print(common.url)
print(common.env)

# %%
with open("/Workspace/Users/maria.rosi2008@gmail.com/Databricks-Practice/Udemy Practice/input.txt", "r") as f:
    print(f.read())

# %%
with open("/Workspace/Users/maria.rosi2008@gmail.com/Databricks-Practice/Udemy Practice/output.txt", "w") as f:
    f.write("This is output txt file")
