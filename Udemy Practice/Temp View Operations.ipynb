# %%
df = spark.read.csv("/Volumes/udemy_practice_catalog/udemy_practice_schema/udemy_practice_volume/orders/orders.csv", header=True)

display(df)

# %%
df.createOrReplaceTempView("orders_temp_view")

# %%
# %sql
SELECT * FROM orders_temp_view

# %%
# %sql
SELECT
  COUNT(DISTINCT order_id) as distint_order_count,
  MIN(order_date) as min_order_date
FROM orders_temp_view
