# %%
# %sql
create table data_dev.bronze.test (
  id int,
  name string
)

# %%
# %sql
select * from data_dev.bronze.test

# %%
# %sql
insert into data_dev.bronze.test values 
(1, 'test')

# %%
# %sql
describe extended data_dev.bronze.test
